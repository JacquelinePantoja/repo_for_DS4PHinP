# %% [markdown]
# <a href="https://colab.research.google.com/github/JacquelinePantoja/repo_for_DS4BIO/blob/main/notebook1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
4 + 4
# Out:
# 8

# %% [markdown]
# This is a text chunk
